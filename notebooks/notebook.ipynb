# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/train_10k.csv')
df
# Out:
#          cell_id              id cell_type  \
# 0       1862f0a6  00001756c60be8      code
# 1       2a9e43d6  00001756c60be8      code
# 2       038b763d  00001756c60be8      code
# 3       2eefe0ef  00001756c60be8      code
# 4       0beab1cd  00001756c60be8      code
# ...          ...             ...       ...
# 460095  6fedf58b  fffbd2e276f908      code
# 460096  8126ba39  fffbd2e276f908      code
# 460097  e8c82f8a  fffbd2e276f908      code
# 460098  5cd2e697  fffbd2e276f908  markdown
# 460099  8d07b78c  fffbd2e276f908  markdown
#
#                                                    source
# 0       # This Python 3 environment comes with many he...
# 1       import numpy as np\nimport pandas as pd\nimpor...
# 2       import warnings\nwarnings.filterwarnings('igno...
# 3           matplotlib.rcParams.update({'font.size': 14})
# 4       def evaluate_preds(train_true_values, train_pr...
# ...                                                   ...
# ...

# %%
df_orders = pd.read_csv('../raw_data/AI4Code/train_orders.csv', nrows=10000)
df_orders['list'] = df_orders['cell_order'].str.split()
df_orders.head()
# Out:
#                id                                         cell_order  \
# 0  00001756c60be8  1862f0a6 448eb224 2a9e43d6 7e2f170a 038b763d 7...
# 1  00015c83e2717b  2e94bd7a 3e99dee9 b5e286ea da4f7550 c417225b 5...
# 2  0001bdd4021779  3fdc37be 073782ca 8ea7263c 80543cd8 38310c80 0...
# 3  0001daf4c2c76d  97266564 a898e555 86605076 76cc2642 ef279279 d...
# 4  0002115f48f982  9ec225f0 18281c6c e3b6b115 4a044c54 365fe576 a...
#
#                                                 list
# 0  [1862f0a6, 448eb224, 2a9e43d6, 7e2f170a, 038b7...
# 1  [2e94bd7a, 3e99dee9, b5e286ea, da4f7550, c4172...
# 2  [3fdc37be, 073782ca, 8ea7263c, 80543cd8, 38310...
# 3  [97266564, a898e555, 86605076, 76cc2642, ef279...
# 4  [9ec225f0, 18281c6c, e3b6b115, 4a044c54, 365fe...

# %%
# Out:
# id
# 7382cfe9df8040    616
# d3d2b4e59be37e    418
# 80986c4b7c0bd3    407
# ca4f5f1c44a0f9    407
# 56a89aec7966b6    392
#                  ...
# 8708109244435f      2
# 4b057f5e5adfb9      2
# eead6354cc52cc      2
# 557f8781eb3a27      2
# 4ac35e8c3f43ef      2
# Name: count, Length: 10000, dtype: int64
